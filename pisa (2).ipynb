# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline
pd.set_option('display.max_columns', 636)

# %%
#!conda update -y -c anaconda matplotlib

# %% [markdown]
# pisa = pd.read_csv('pisa2012.csv', encoding='latin-1',
#        index_col=0,
#        dtype={15: str, 16: str, 17: str, 21: str, 22: str, 23: str, 24: str, 25: str, 26: str, 37: str,
#            45: str, 65: str, 123: str, 156: str, 157: str, 158: str, 159: str, 160: str, 161: str,
#            162: str, 163: str, 164: str, 165: str, 166: str, 167: str, 168: str, 169: str, 170: str,
#            171: str, 284: str, 285: str, 286: str, 287: str, 288: str, 289: str, 290: str, 291: str,
#            292: str, 293: str, 294: str, 295: str, 296: str, 297: str, 298: str, 299: str, 300: str,
#            301: str, 302: str, 303: str, 307: str, 308: str, 309: str, 310: str, 311: str, 312: str,
#            313: str, 314: str, 315: str, 316: str, 317: str, 318: str, 319: str, 320: str, 321: str,
#            322: str, 323: str, 324: str, 325: str, 326: str, 327: str, 328: str, 329: str, 330: str,
#            331: str, 332: str, 333: str, 334: str, 335: str, 336: str, 337: str, 338: str, 339: str,
#            340: str, 341: str, 342: str, 343: str, 344: str, 345: str, 346: str, 347: str, 348: str,
#            349: str, 350: str, 351: str, 352: str, 353: str, 354: str, 355: str, 356: str, 357: str,
#            376: str, 377: str, 378: str, 379: str, 380: str, 381: str, 382: str, 383: str, 384: str,
#            385: str, 386: str, 387: str, 388: str, 389: str, 390: str, 391: str, 392: str, 393: str,
#            394: str, 395: str, 396: str, 397: str, 398: str, 399: str, 400: str, 401: str, 402: str,
#            403: str, 475: str, 30: str, 31: str, 36: str, 155: str}
# )

# %% [markdown]
# raw.shape

# %% [markdown]
# raw.head()

# %% [markdown]
# raw = raw[['STIDSTD','ST04Q01','CNT','PV1MATH','PV1READ','PV1SCIE','ST11Q01','ST11Q02','ST57Q05','HISCED','ST87Q01' ,'ST87Q06' ,'ST87Q07' ]]

# %% [markdown]
# raw.rename({'STIDSTD':'Student Id', 'ST04Q01':'Gender','CNT':'Country',
#              'PV1MATH':'Math Score', 'PV1READ':"Reading Score",'PV1SCIE':'Science Score',
#              'ST11Q01':'Mother Present', 'ST11Q02':'Father Present',
#            'ST87Q01':'Feel Like Outsider',
#  'ST87Q06'  : 'Feel Lonely at School'  ,
#  'ST87Q07'  : 'Feel Happy at School' },
#             axis='columns', inplace=True)

# %% [markdown]
# raw.shape

# %% [markdown]
# raw.to_csv('pisa_filtered.csv')

# %% [markdown]
# ## Data Assessment

# %%
df=pd.read_csv('pisa_filtered.csv')

# %%
df.shape
# Out:
# (485490, 13)

# %%
df.head()
# Out:
#    Unnamed: 0  Student Id  Gender  Country  Math Score  Reading Score  \
# 0           1           1  Female  Albania    406.8469       249.5762
# 1           2           2  Female  Albania    486.1427       406.2936
# 2           3           3  Female  Albania    533.2684       401.2100
# 3           4           4  Female  Albania    412.2215       547.3630
# 4           5           5  Female  Albania    381.9209       311.7707
#
#    Science Score Mother Present Father Present             HISCED  \
# 0       341.7009            Yes            Yes  ISCED 3A, ISCED 4
# 1       548.9929            Yes            Yes        ISCED 5A, 6
# 2       499.6643            Yes            Yes        ISCED 5A, 6
# 3       438.6796            Yes            Yes        ISCED 5A, 6
# 4       361.5628            Yes            Yes  ISCED 3A, ISCED 4
#
#   Feel Like Outsider Feel Lonely at School Feel Happy at School
# 0              Agree     Strongly disagree                Agree
# 1                NaN                   NaN                  NaN
# 2                NaN                   NaN                  NaN
# 3                NaN                   NaN                  NaN
# 4  Strongly disagree     Strongly disagree       Strongly agree

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Student Id', 'Gender', 'Country', 'Math Score',
#        'Reading Score', 'Science Score', 'Mother Present', 'Father Present',
#        'HISCED', 'Feel Like Outsider', 'Feel Lonely at School',
#        'Feel Happy at School'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Student Id                    0
# Gender                        0
# Country                       0
# Math Score                    0
# Reading Score                 0
# Science Score                 0
# Mother Present            24931
# Father Present            44454
# HISCED                    12399
# Feel Like Outsider       173714
# Feel Lonely at School    174538
# Feel Happy at School     175209
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Student Id                    0
# Gender                        0
# Country                       0
# Math Score                    0
# Reading Score                 0
# Science Score                 0
# Mother Present            24931
# Father Present            44454
# HISCED                    12399
# Feel Like Outsider       173714
# Feel Lonely at School    174538
# Feel Happy at School     175209
# dtype: int64

# %%
df.loc[((df['Father Present']== "Yes") & (df['Mother Present'] == "Yes")), "Parent"] = "Both"
df.loc[((df['Father Present']== "No") & (df['Mother Present'] == "Yes")), "Parent"] = "Mother"
df.loc[((df['Father Present']== "Yes") & (df['Mother Present'] == "No")), "Parent"] = "Father"
df.loc[((df['Father Present']== "No") & (df['Mother Present'] == "No")), "Parent"] = "None"

# %%
df['Average']=(df['Math Score']+df['Science Score']+df['Reading Score'])/3

# %%
df.Parent.value_counts()
# Out:
# Both      360003
# Mother     50002
# None       18633
# Father      8262
# Name: Parent, dtype: int64

# %% [markdown]
# ## Outsider index

# %%
df['Outsider_index']=np.NaN
df.loc[(df['Feel Like Outsider']== "Strongly agree") , "Outsider_index"] = "4"
df.loc[(df['Feel Like Outsider']== "Agree") , "Outsider_index"] = "3"
df.loc[(df['Feel Like Outsider']== "Disagree") , "Outsider_index"] = "2"
df.loc[(df['Feel Like Outsider']== "Strongly disagree") , "Outsider_index"] = "1"

# %%
df['Outsider_index'].value_counts()
# Out:
# 2    137026
# 1    132996
# 3     27910
# 4     13844
# Name: Outsider_index, dtype: int64

# %% [markdown]
# ## Loneliness index

# %%
df['Loneliness_index']=np.NaN
df.loc[(df['Feel Lonely at School']== "Strongly agree") , "Loneliness_index"] = "4"
df.loc[(df['Feel Lonely at School']== "Agree") , "Loneliness_index"] = "3"
df.loc[(df['Feel Lonely at School']== "Disagree") , "Loneliness_index"] = "2"
df.loc[(df['Feel Lonely at School']== "Strongly disagree") , "Loneliness_index"] = "1"
df['Loneliness_index'].value_counts()
# Out:
# 1    149574
# 2    125801
# 3     25413
# 4     10164
# Name: Loneliness_index, dtype: int64

# %% [markdown]
# ## Happiness Index

# %%
df['Happiness_index']=np.NaN
df.loc[(df['Feel Happy at School']== "Strongly agree") , "Happiness_index"] = "1"
df.loc[(df['Feel Happy at School']== "Agree") , "Happiness_index"] = "2"
df.loc[(df['Feel Happy at School']== "Disagree") , "Happiness_index"] = "3"
df.loc[(df['Feel Happy at School']== "Strongly disagree") , "Happiness_index"] = "4"
df['Happiness_index'].value_counts()
# Out:
# 2    170734
# 1     84836
# 3     42143
# 4     12568
# Name: Happiness_index, dtype: int64

# %%
df['Feel Happy at School'].value_counts()
# Out:
# Agree                170734
# Strongly agree        84836
# Disagree              42143
# Strongly disagree     12568
# Name: Feel Happy at School, dtype: int64

# %%
 df.dropna()
# Out:
#         Unnamed: 0  Student Id  Gender  Country  Math Score  Reading Score  \
# 0                1           1  Female  Albania    406.8469       249.5762
# 4                5           5  Female  Albania    381.9209       311.7707
# 5                6           6  Female  Albania    396.3312       378.2544
# 6                7           7  Female  Albania    438.0823       373.2503
# 7                8           8    Male  Albania    576.5773       567.7589
# ...            ...         ...     ...      ...         ...            ...
# 485483      485484        4953  Female  Vietnam    526.1022       482.3090
# 485484      485485        4954    Male  Vietnam    500.4752       433.8340
# 485486      485487        4956    Male  Vietnam    518.9360       490.9325
# 485487      485488        4957    Male  Vietnam    475.2376       462.6239
# 485488      485489        4958    Male  Vietnam    550.9503       505.2873
#
#         Science Score Mother Present Father Present             HISCED  \
# 0            341.7009            Yes            Yes  ISCED 3A, ISCED 4
# 4            361.5628            Yes            Yes  ISCED 3A, ISCED 4
# 5            384.3156            Yes            Yes        ISCED 3B, C
# 6            508.1499            Yes            Yes        ISCED 5A, 6
# 7            611.2831            Yes            Yes        ISCED 5A, 6
# ...               ...            ...            ...                ...
# 485483       533.4204            Yes             No  ISCED 3A, ISCED 4
# 485484       480.6416            Yes            Yes            ISCED 1
# 485486       538.7355            Yes            Yes            ISCED 2
# 485487       536.8706            Yes            Yes            ISCED 2
# 485488       511.0407            Yes            Yes        ISCED 5A, 6
#
#        Feel Like Outsider Feel Lonely at School Feel Happy at School  Parent  \
# 0                   Agree     Strongly disagree                Agree    Both
# 4       Strongly disagree     Strongly disagree       Strongly agree    Both
# 5                Disagree     Strongly disagree                Agree    Both
# 6       Strongly disagree     Strongly disagree       Strongly agree    Both
# 7                Disagree        Strongly agree                Agree    Both
# ...                   ...                   ...                  ...     ...
# 485483  Strongly disagree     Strongly disagree                Agree  Mother
# 485484  Strongly disagree     Strongly disagree       Strongly agree    Both
# 485486           Disagree              Disagree             Disagree    Both
# 485487  Strongly disagree              Disagree                Agree    Both
# 485488  Strongly disagree     Strongly disagree                Agree    Both
#
#            Average Outsider_index Loneliness_index Happiness_index
# 0       332.708000              3                1               2
# 4       351.751467              1                1               1
# 5       386.300400              2                1               2
# 6       439.827500              1                1               1
# 7       585.206433              2                4               2
# ...            ...            ...              ...             ...
# 485483  513.943867              1                1               2
# 485484  471.650267              1                1               1
# 485486  516.201333              2                2               3
# 485487  491.577367              1                2               2
# 485488  522.426100              1                1               2
#
# [276618 rows x 18 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  Student Id  Gender  Country  Math Score  Reading Score  \
# 0           1           1  Female  Albania    406.8469       249.5762
# 1           2           2  Female  Albania    486.1427       406.2936
# 2           3           3  Female  Albania    533.2684       401.2100
# 3           4           4  Female  Albania    412.2215       547.3630
# 4           5           5  Female  Albania    381.9209       311.7707
#
#    Science Score Mother Present Father Present             HISCED  \
# 0       341.7009            Yes            Yes  ISCED 3A, ISCED 4
# 1       548.9929            Yes            Yes        ISCED 5A, 6
# 2       499.6643            Yes            Yes        ISCED 5A, 6
# 3       438.6796            Yes            Yes        ISCED 5A, 6
# 4       361.5628            Yes            Yes  ISCED 3A, ISCED 4
#
#   Feel Like Outsider Feel Lonely at School Feel Happy at School Parent  \
# 0              Agree     Strongly disagree                Agree   Both
# 1                NaN                   NaN                  NaN   Both
# 2                NaN                   NaN                  NaN   Both
# 3                NaN                   NaN                  NaN   Both
# 4  Strongly disagree     Strongly disagree       Strongly agree   Both
#
#       Average Outsider_index Loneliness_index Happiness_index
# 0  332.708000              3                1               2
# 1  480.476400            NaN              NaN             NaN
# 2  478.047567            NaN              NaN             NaN
# 3  466.088033            NaN              NaN             NaN
# 4  351.751467              1                1               1

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# Student Id                 int64
# Gender                    object
# Country                   object
# Math Score               float64
# Reading Score            float64
# Science Score            float64
# Mother Present            object
# Father Present            object
# HISCED                    object
# Feel Like Outsider        object
# Feel Lonely at School     object
# Feel Happy at School      object
# Parent                    object
# Average                  float64
# Outsider_index            object
# Loneliness_index          object
# Happiness_index           object
# dtype: object

# %%
df['Outsider_index']=df['Outsider_index'].astype(float)
df['Loneliness_index']=df['Loneliness_index'].astype(float)
df['Loneliness_index']=df['Loneliness_index'].astype(float)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Parent Presence

# %%
parent_counts = df['Parent'].value_counts()
parent_order=parent_counts.index

# %%
plt.figure(figsize=(12,4))
base_color = sb.color_palette()[0]
sb.countplot(data=df, y='Parent', color=base_color, order=parent_order);


# Logic to print the proportion text on the bars
for i in range (parent_counts.shape[0]):
    # Remember, type_counts contains the frequency of unique values in the `type` column in decreasing order.
    count = parent_counts[i]
    # Convert count into a percentage, and then into string
    string1 = '{:0.1f}'.format(count/1000)
    string2=string1 + 'k'
    # Print the string value on the bar. 
    plt.text(count+1, i, string2, va='center')

plt.title('Parent Presence Distribution');

# %% [markdown]
# ### Mood Check

# %% [markdown]
# How is the general mood of students.
# Potisive feelings are set to 1 and increase in index means feelings become negative.
# It is observed that

# %%
fig, ax =plt.subplots(1,3,figsize=(23, 5))

ax[0].set_title("Feeling Outside Index")
sb.countplot(data=df, y='Outsider_index',color=base_color,ax=ax[0]);
ax[1].set_title("Loneliness Index");
sb.countplot(data=df, y='Loneliness_index', color=base_color,ax=ax[1]);
ax[2].set_title("Happiness Index");
sb.countplot(data=df, y='Happiness_index', color=base_color,ax=ax[2]);

# %% [markdown]
# ### Test Scores

# %%
Test scores for all of the test results are normally distributed and all of the scores are centered around 500.
Most of the students' scores are between 350 and 650 points.
# Out:
#   File "<ipython-input-25-4b61a5427a3d>", line 1
#     Test scores for all of the test results are normally distributed and all of the scores are centered around 500.
#               ^
# SyntaxError: invalid syntax

# %%
#ASK: RANGE AND XTICKS
#show mean 
f, ax = plt.subplots(1, 4, figsize=(23, 4), sharex=True)
plt.yticks([0.001,0.002,0.003,0.004])

ax[0].set_title("Distribution of Average Scores")
sb.distplot(df['Average'], bins=20,ax=ax[0]);
plt.yticks([0.001,0.002,0.003,0.004]);

ax[1].set_title("Distribution of Math Scores")
sb.distplot(df['Math Score'],bins=20,ax=ax[1]);
plt.yticks([0.001,0.002,0.003,0.004]);

ax[2].set_title("Distribution of Reading Scores")
sb.distplot(df['Reading Score'], bins=20,ax=ax[2]);
plt.yticks([0.001,0.002,0.003,0.004]);


ax[3].set_title("Distribution of Science Scores")
sb.distplot(df['Science Score'], bins=20,ax=ax[3]);
plt.yticks([0.001,0.002,0.003,0.004]);

# %% [markdown]
# ## Bivariate Exploration

# %% [markdown]
# ## How is the loss of a parent affects scores?
# It is observed that the loss of parent has negative affect on scores and students who lost both parent has the lowest scores.

# %%
sb.violinplot(data = df,x ='Parent', y ='Average', color=base_color, innner=None);

# %%
f, ax = plt.subplots(1, 3, figsize=(23, 7), sharex=True)
sb.violinplot(data = df,x ='Parent', y ='Math Score', color=base_color, innner=None,ax=ax[0]);
sb.violinplot(data = df,x ='Parent', y ='Science Score', color=base_color, innner=None,ax=ax[1]);
sb.violinplot(data = df,x ='Parent', y ='Reading Score', color=base_color, innner=None,ax=ax[2]);

# %% [markdown]
# ## What is the correlation  between scores and feelings?
# All of the scores are strongly corelated, science and math scıres have the strongest correlation.
# Feeling outsider and feeling lonely has negative but insignificant correlation.

# %%
sb.heatmap(data=df[['Reading Score','Math Score','Science Score','Outsider_index','Loneliness_index','Happiness_index']].corr(),annot=True);

# %% [markdown]
# ## How is feeling outsider, feeling of loneliness, presence of parents and average scores are related?
# We understand  student who feel more lonely and outsider has lower average scores regardless of the presence of parents. Also loss of parent has a negative affect on average results. Which was also observed above.
# It is also observed that varibility is bigger when both parents are not present.  Variability in average scores is highest when only father is present.

# %%
f, ax = plt.subplots(1, 2, figsize=(23, 7), sharex=True)
#sb.violinplot(data = df,x ='Parent', y ='Happiness_index', color=base_color, innner=None,ax=ax[0]);
sb.pointplot(data = df,x ='Loneliness_index', y ='Average', hue='Parent', color=base_color,inner=None,palette="Set2",ax=ax[0]);
sb.pointplot(data = df,x ='Outsider_index', y ='Average', hue='Parent', color=base_color,inner=None,palette="Set2",ax=ax[1]);
#sb.violinplot(data = df,x ='Parent', y ='Outsider_index', color=base_color, innner=None,ax=ax[2]);

# %% [markdown]
# ## How is happiness, presence of parents and average scores are related?
# There is no strong correlation found in feeling of happiness. Also loss of parent has a negative affect on average results.
# It is also observed that varibility is bigger when both parents are not present.  Variability in average scores is highest when only father is present.

# %%
plt.figure(figsize=(12,4))
sb.pointplot(data = df,x ='Happiness_index', y ='Average', hue='Parent', color=base_color,inner=None,palette="Set2");

# %%
df.describe()
# Out:
#           Unnamed: 0     Student Id     Math Score  Reading Score  \
# count  485490.000000  485490.000000  485490.000000  485490.000000
# mean   242745.500000    6134.066201     469.621653     472.004640
# std    140149.035431    6733.144944     103.265391     102.505523
# min         1.000000       1.000000      19.792800       0.083400
# 25%    121373.250000    1811.000000     395.318600     403.600700
# 50%    242745.500000    3740.000000     466.201900     475.455000
# 75%    364117.750000    7456.000000     541.057800     544.502500
# max    485490.000000   33806.000000     962.229300     904.802600
#
#        Science Score        Average  Outsider_index  Loneliness_index
# count  485490.000000  485490.000000   311776.000000     310952.000000
# mean      475.769824     472.465373        1.751751          1.666080
# std       101.464426      98.200972        0.795037          0.762884
# min         2.648300      21.907100        1.000000          1.000000
# 25%       404.457300     403.287467        1.000000          1.000000
# 50%       475.699400     472.234633        2.000000          2.000000
# 75%       547.780700     542.232208        2.000000          2.000000
# max       903.338300     875.868167        4.000000          4.000000

# %%
plt.hist2d(data=df, x='Happiness_Index',y='Average');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-a9aef75b00db> in <module>
# ----> 1 plt.hist2d(data=df, x='Happiness_Index',y='Average');
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist2d(x, y, bins, range, density, weights, cmin, cmax, data, **kwargs)
#    2651         x, y, bins=bins, range=range, density=density,
#    2652         weights=weights, cmin=cmin, cmax=cmax, **({"data": data} if
# -> 2653         data is not None else {}), **kwargs)
#    2654     sci(__ret[-1])
#    2655     return __ret
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1637                 bound.arguments.setdefault(varkwargs_name, {})["label"] = label
#    1638
# -> 1639         return func(*bound.args, **bound.kwargs)
#    1640
#    1641     inner.__doc__ = _add_data_doc(inner.__doc__, replace_names)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist2d(self, x, y, bins, range, density, weights, cmin, cmax, **kwargs)
#    7065
#    7066         h, xedges, yedges = np.histogram2d(x, y, bins=bins, range=range,
# -> 7067                                            normed=density, weights=weights)
#    7068
#    7069         if cmin is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\twodim_base.py in histogram2d(x, y, bins, range, normed, weights, density)
#     712         xedges = yedges = asarray(bins)
#     713         bins = [xedges, yedges]
# --> 714     hist, edges = histogramdd([x, y], bins, range, normed, weights, density)
#     715     return hist, edges[0], edges[1]
#     716
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py in histogramdd(sample, bins, range, normed, weights, density)
#    1039                 raise ValueError(
#    1040                     '`bins[{}]` must be positive, when an integer'.format(i))
# -> 1041             smin, smax = _get_outer_edges(sample[:,i], range[i])
#    1042             edges[i] = np.linspace(smin, smax, bins[i] + 1)
#    1043         elif np.ndim(bins[i]) == 1:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\histograms.py in _get_outer_edges(a, range)
#     310         first_edge, last_edge = 0, 1
#     311     else:
# --> 312         first_edge, last_edge = a.min(), a.max()
#     313         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     314             raise ValueError(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial)
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1115                     result = method(y)
#    1116                 if result is NotImplemented:
# -> 1117                     return invalid_comparison(x, y, op)
#    1118             else:
#    1119                 result = op(x, y)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in invalid_comparison(left, right, op)
#     495         raise TypeError(
#     496             "Invalid comparison between dtype={dtype} and {typ}".format(
# --> 497                 dtype=left.dtype, typ=type(right).__name__
#     498             )
#     499         )
#
# TypeError: Invalid comparison between dtype=float64 and str

# %%
sb.regplot(data=df, x='Happiness_Index',y='Average');
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Happiness_Index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-833bd652a13a> in <module>
# ----> 1 sb.regplot(data=df, x='Happiness_Index',y='Average');
#       2 plt.xlabel('Displacement (1)')
#       3 plt.ylabel('Combined Fuel Eff. (mpg)')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     779                                  order, logistic, lowess, robust, logx,
#     780                                  x_partial, y_partial, truncate, dropna,
# --> 781                                  x_jitter, y_jitter, color, label)
#     782
#     783     if ax is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     103         # Extract the data vals from the arguments or passed dataframe
#     104         self.establish_variables(data, x=x, y=y, units=units,
# --> 105                                  x_partial=x_partial, y_partial=y_partial)
#     106
#     107         # Drop null observations
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in establish_variables(self, data, **kws)
#      46         for var, val in kws.items():
#      47             if isinstance(val, string_types):
# ---> 48                 setattr(self, var, data[val])
#      49             elif isinstance(val, list):
#      50                 setattr(self, var, np.asarray(val))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Happiness_Index'

# %%
#ybins=np.arange(1000,1300+1000,1000)
#xbins=np.arange(-1,5,1)
df['Happiness_index']=df['Happiness_index'].astype(float)
df['Average']=df['Average'].astype(float)
sb.regplot(data=df, x='Happiness_Index',y='Average');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Happiness_Index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-0b1a92d5c008> in <module>
#       3 df['Happiness_index']=df['Happiness_index'].astype(float)
#       4 df['Average']=df['Average'].astype(float)
# ----> 5 sb.regplot(data=df, x='Happiness_Index',y='Average');
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     779                                  order, logistic, lowess, robust, logx,
#     780                                  x_partial, y_partial, truncate, dropna,
# --> 781                                  x_jitter, y_jitter, color, label)
#     782
#     783     if ax is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     103         # Extract the data vals from the arguments or passed dataframe
#     104         self.establish_variables(data, x=x, y=y, units=units,
# --> 105                                  x_partial=x_partial, y_partial=y_partial)
#     106
#     107         # Drop null observations
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in establish_variables(self, data, **kws)
#      46         for var, val in kws.items():
#      47             if isinstance(val, string_types):
# ---> 48                 setattr(self, var, data[val])
#      49             elif isinstance(val, list):
#      50                 setattr(self, var, np.asarray(val))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Happiness_Index'
